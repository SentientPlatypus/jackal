# %% [markdown]
# # Testing Roadmap
#
# THe robot needs to follow a human, however, if a human goes outside of wall boundaries, the robot will not be able to follow. THerefore, we simply project the human's position onto the robot's roadmap, and the robot will go the closest it can.

# %% [markdown]
# first, lets import the roadmap class we made in roadmap.py

# %%
from roadmap import RoadMap

# %% [markdown]
# Roadmap takes in walls, and waypoints. Thats it.  Well, make sure the walls are previously *bloated*

# %%
rm = RoadMap("rhd3_map_3_walls.txt", "rhd3_map_3_waypoints.txt")
human = [10, -9]
rm.plot(human = human)
# Out:
# ----Initialized-----
# roadmap:
# array([[[  6.94526854,  -0.1258312 ],
#         [  0.10659847,   0.07549872]],
#
#        [[  6.94526854,  -0.1258312 ],
#         [  3.12      ,  -0.05872123]],
#
#        [[  6.94526854,  -0.1258312 ],
#         [ 10.30076726,  -0.3942711 ]],
#
#        [[  8.01902813,  -8.7830179 ],
#         [ 11.84429668, -12.80961637]],
#
#        [[  8.01902813,  -8.7830179 ],
#         [ 15.46823529, -16.70199488]],
#
#        [[  8.01902813,  -8.7830179 ],
#         [  6.5426087 ,  -6.97104859]],
#
#        [[  8.01902813,  -8.7830179 ],
#         [  9.89810742, -10.72920716]],
#
#        [[  8.01902813,  -8.7830179 ],
#         [ 14.05892583, -15.15846547]],
#
#        [[  8.01902813,  -8.7830179 ],
#         [ 17.61575448, -18.78240409]],
#
#        [[ 11.84429668, -12.80961637],
#         [  8.01902813,  -8.7830179 ]],
#
#        [[ 11.84429668, -12.80961637],
#         [ 15.46823529, -16.70199488]],
#
#        [[ 11.84429668, -12.80961637],
# ...

# %% [markdown]
# # Testing
